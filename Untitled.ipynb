# %%
import pandas as pd
df = pd.read_csv("Desktop/datasets/Train_v2.csv")

# %%
df.head(5)
# Out:
#   country  year    uniqueid bank_account location_type cellphone_access  \
# 0   Kenya  2018  uniqueid_1          Yes         Rural              Yes
# 1   Kenya  2018  uniqueid_2           No         Rural               No
# 2   Kenya  2018  uniqueid_3          Yes         Urban              Yes
# 3   Kenya  2018  uniqueid_4           No         Rural              Yes
# 4   Kenya  2018  uniqueid_5           No         Urban               No
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 24               Female
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
#
#   relationship_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# ...

# %%
df["job_type"].unique()
# Out:
# array(['Self employed', 'Government Dependent',
#        'Formally employed Private', 'Informally employed',
#        'Formally employed Government', 'Farming and Fishing',
#        'Remittance Dependent', 'Other Income',
#        'Dont Know/Refuse to answer', 'No Income'], dtype=object)

# %%
location_type_dict = {"Rural": 0, "Urban": 1}
cellphone_access_dict = {"No":0, "Yes": 1}
education_level_dict = {"No formal education": 1, "Primary education": 2, "Secondary education": 3, "Vocational/Specialised training": 4, "Tetiary education": 5, "Other/Dont Know/RTA": 0}
df["location_type"] = df["location_type"].map(location_type_dict)
df["cellphone_access"] = df["cellphone_access"].map(cellphone_access_dict)
df["education_level"] = df["education_level"].map(education_level_dict)

df.head()
# Out:
#   country  year    uniqueid bank_account  location_type  cellphone_access  \
# 0   Kenya  2018  uniqueid_1          Yes            NaN               NaN
# 1   Kenya  2018  uniqueid_2           No            NaN               NaN
# 2   Kenya  2018  uniqueid_3          Yes            NaN               NaN
# 3   Kenya  2018  uniqueid_4           No            NaN               NaN
# 4   Kenya  2018  uniqueid_5           No            NaN               NaN
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 24               Female
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
#
#   relationship_with_head           marital_status  education_level  \
# 0                 Spouse  Married/Living together              NaN
# ...
