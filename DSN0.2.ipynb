# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df_train = pd.read_csv("/home/felix/Desktop/dsn/train.csv", index_col=0)
df_test = pd.read_csv("/home/felix/Desktop/dsn/test.csv")

# %%
df_train.tail()
# Out:
#                                                 Division        Qualification  \
# EmployeeNo
# YAK/S/54802  Information Technology and Solution Support  First Degree or HND
# YAK/S/54805        Customer Support and Field Operations     MSc, MBA and PhD
# YAK/S/54806                     Information and Strategy  First Degree or HND
# YAK/S/54807               Commercial Sales and Marketing                  NaN
# YAK/S/54808                         People/HR Management  First Degree or HND
#
#              Gender   Channel_of_Recruitment  Trainings_Attended  \
# EmployeeNo
# YAK/S/54802  Female  Direct Internal process                   2
# YAK/S/54805  Female        Agency and others                   2
# YAK/S/54806    Male        Agency and others                   2
# YAK/S/54807    Male  Direct Internal process                   2
# YAK/S/54808    Male        Agency and others                   2
#
#              Year_of_birth  Last_performance_score  Year_of_recruitment  \
# ...

# %%
df_train.isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-60087dc5eeb8> in <module>
# ----> 1 df_train.isnull()
#
# NameError: name 'df_train' is not defined
